# %%
import pandas as pd
import numpy as np

df = pd.read_csv("sample.csv",encoding = "ISO-8859-1")
#df.describe(include = 'all')

# %%
print(df.head())
#df.Year = str(df.Year)
#print(df.describe())
#print("\n Datatype: ",df.Product.dtype.name)
#print(df.head())

# %%
def adder(a,b):
    return (a+b)

#dx = df.Year.pipe(adder,20)
#df.Year = dx
print(df.head())
df1 = df[['Year','Units']]
dy = df1.apply(np.mean)

print(dy)


df2 = df[df.Year>2014]; print(df2)
# Out:
#                                              Product                User  \
# 0   Eldon Base for stackable storage shelf, platinum  Muhammed MacIntyre
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Barry French
# 2   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl        Barry French
# 3                                               R380       Clay Rozendal
# 4                           Holmes HEPA Air Purifier      Carlos Soltero
#
#    Units                        Category    Year
# 0      2          Storage & Organization  2155.0
# 1      3                      Appliances  2153.0
# 2      1  Binders and Binder Accessories  2154.0
# 3      4    Telephones and Communication  2152.0
# 4      2                      Appliances  2156.0
# Year     2154.18
# Units       2.29
# dtype: float64
#                                               Product                User  \
# 0    Eldon Base for stackable storage shelf, platinum  Muhammed MacIntyre
# ...
